# %%
import pandas as pd
import numpy as np

from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

from util_koyak import col_selector, grid_estimator
# Out:
# /home/pnietoramos/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn")
# %matplotlib inline

# %%
def conf_plot(y, y_pred):
    plt.figure(dpi=180)
    sns.heatmap(confusion_matrix(y, y_pred), cmap=plt.cm.Blues, annot=True, square=True, fmt='d', annot_kws={"size": 15});
    plt.xlabel('prediction')
    plt.ylabel('actual');

# %%
df_genre = pd.read_csv("features_genre_6.csv", index_col=0)
df_genre.head()
# Out:
#           ('chroma_cens', 'kurtosis', '01')  \
# track_id
# 2                                  7.180653
# 3                                  1.888963
# 5                                  0.527563
# 10                                 3.702245
# 134                                0.918445
#
#           ('chroma_cens', 'kurtosis', '02')  \
# track_id
# 2                                  5.230309
# 3                                  0.760539
# 5                                 -0.077654
# 10                                -0.291193
# 134                                0.674147
#
#           ('chroma_cens', 'kurtosis', '03')  \
# track_id
# 2                                  0.249321
# 3                                  0.345297
# 5                                 -0.279610
# 10                                 2.196742
# 134                                0.577818
#
#           ('chroma_cens', 'kurtosis', '04')  \
# track_id
# 2                                  1.347620
# ...

# %%
df_mfcc_cont = col_selector(['mfcc','contrast'], df_genre)

# %%
df_mfcc_cont.head()
# Out:
#           ('mfcc', 'kurtosis', '01')  ('mfcc', 'kurtosis', '02')  \
# track_id
# 2                           3.856789                    1.541901
# 3                           4.296755                    1.399977
# 5                           2.624517                    2.415293
# 10                          5.076893                    1.161854
# 134                         1.559808                    0.840775
#
#           ('mfcc', 'kurtosis', '03')  ('mfcc', 'kurtosis', '04')  \
# track_id
# 2                           0.000816                    0.330728
# 3                           0.112535                   -0.211170
# 5                           0.440233                   -0.782131
# 10                          2.095651                    1.372743
# 134                        -0.171289                   -0.265671
#
#           ('mfcc', 'kurtosis', '05')  ('mfcc', 'kurtosis', '06')  \
# track_id
# 2                           0.118731                   -0.342687
# ...

# %%
X = df_mfcc_cont.drop("genre_top",axis=1)
y = df_mfcc_cont["genre_top"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.10,stratify=y, random_state=4444)

# %%
sca = StandardScaler()
X_train_sca = sca.fit_transform(X_train)
X_test_sca = sca.transform(X_test);

# %%
param_grid = {}
grid_estimator(SVC(), param_grid, X_train_sca, y_train, X_test_sca, y_test)
# Out:
# Accuracy training: 0.72300591225
# Accuracy test: 0.737456242707
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ### Hyperparameter Tunning

# %%
np.logspace(-2,1,6)
# Out:
# array([  0.01      ,   0.03981072,   0.15848932,   0.63095734,
#          2.51188643,  10.        ])

# %%
param_grid = {'C': np.logspace(-2,1,6)}
grid_estimator(SVC(), param_grid, X_train_sca, y_train, X_test_sca, y_test)
# Out:
# Accuracy training: 0.730110984338
# Accuracy test: 0.74772462077
# SVC(C=2.5118864315095797, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
param_grid = {'C': [2.512], 'gamma': [0.001, 0.01, 0.1, 1, 10]}
grid_estimator(SVC(), param_grid, X_train_sca, y_train, X_test_sca, y_test)
# Out:
# Accuracy training: 0.731277875739
# Accuracy test: 0.75309218203
# SVC(C=2.512, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ### Plotting the best model

# %%
svc = SVC(C=2.512)
svc.fit(X_train_sca, y_train)
y_pred = svc.predict(X_test_sca)
conf_plot(y_test, y_pred)

# %% [markdown]
# ### Trying with SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
X_smoted, y_smoted = SMOTE(random_state=42).fit_sample(X_train_sca,y_train)

# %%
svc = SVC(C=2.512)
svc.fit(X_smoted, y_smoted)
y_pred = svc.predict(X_test_sca)
conf_plot(y_test, y_pred)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7381563593932322

# %%
accuracy_score(y_smoted, svc.predict(X_smoted))
# Out:
# 0.9504596260315471

# %% [markdown]
# ### SMOTE before splitting

# %%
from imblearn.over_sampling import SMOTE

# %%
X = df_mfcc_cont.drop("genre_top",axis=1)
y = df_mfcc_cont["genre_top"]

# %%
X_smoted, y_smoted = SMOTE(random_state=42).fit_sample(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_smoted, y_smoted, test_size=.10,stratify=y, random_state=4444)

# %%
sca = StandardScaler()
X_train_sca = sca.fit_transform(X_train)
X_test_sca = sca.transform(X_test);

# %%
svc = SVC(C=2.512)
svc.fit(X_train_sca, y_train)
y_pred = svc.predict(X_test_sca)

# %%
conf_plot(y_test, y_pred)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7477246207701284

# %%
accuracy_score(y_train, svc.predict(X_train_sca))
# Out:
# 0.8886007675552329

# %% [markdown]
# #### Tunning with SMOTE

# %%
param_grid = {'C': np.logspace(-2,1,6)}
grid_estimator(SVC(), param_grid, X_smoted, y_smoted, X_test_sca, y_test)
# Out:
# Accuracy training: 0.910359866290609
# Accuracy test: 0.73512252042007
# SVC(C=10.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
